# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
df_tips.head()

# %%
#variáveis da função relplot
sns.relplot(x='dependente', y='independente', palette='blues', hue='class_cores', style='class_formas', size='tamanho', sizes=(15,300), data=tips)

#variáveis da função scatterplot
sns.scatterplot(x='dependente', y='independente', hue='class_cores', style='class_formas', data=tips)

#aumentar tamanho da figura
f, ax=plt.subplots(figsize=(15,7))

#grafico de barras
with sns.color_paletter('Accent')
sns.catplot(x='sex', kind='count', palette='Set2', data=tips)

#heat map
sns.heatmap(tips.corr(), annot=True, cmap='PiYG')

#setar paleta
sns.set_palette('pastel')
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', hue='sex', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='sex', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', hue='size', data=tips)

# %%
sns.scatterplot(x='total_bill', y='tip', hue='day', style='time', data=tips)

# %%
import matplotlib.pyplot as plt
f, ax=plt.subplots(figsize=(15,7))
sns.scatterplot(x='total_bill', y='tip', hue='day', style='time', data=tips)

# %%
sns.catplot(x='sex', kind='count', palette='Set2', data=tips)

# %%
sns.heatmap(tips.corr(), annot=True, cmap='PiYG')
